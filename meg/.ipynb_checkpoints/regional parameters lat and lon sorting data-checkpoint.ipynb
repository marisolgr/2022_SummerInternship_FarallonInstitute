# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt 
import datetime as dt
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import warnings 
import matplotlib.dates as mdates
import glob
import os

warnings.simplefilter('ignore') 

from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from calendar import month_abbr

# %%
# great job megan!
# i think the problem is the non uniform data. i think.
# so, lets use time not as a coordinate, but as another variable, 
# and as coordinate, use a uniformily increasing index.

# then, do these next steps:
#   - give the lat lon rrange as input arguments in the function, so we don't have to type them every time
#   - document the function (inside the func): what it does, describe input output, author and date
#   - make a final map with all the data for the region (inside the function)

# %%
ddir = '../saildrone_data/'
fns = glob.glob(ddir+'*.nc')
fns
# Out:
# ['../saildrone_data/saildrone-gen_5-arctic_misst_2019-sd1037-20190514T230000-20191011T183000-1_minutes-v1.1575487464625_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1029_2018_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-arctic_misst_2019-sd1036-20190514T230000-20191011T183000-1_minutes-v1.1575336154680_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1005_2018_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2018_sd1024_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-1021_atlantic-sd1021-20190525T000000-20191021T235959-1_minutes-v1.1571806429446_(1)_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/PMEL_Arctic_2016_sd126-ALL-1_min-v1_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1038_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/PMEL_Arctic_2016_sd128-ALL-1_min-v1_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1047_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_sd1041_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1066_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_sd1033_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2018_sd1026_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_sd1035_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1030_2018_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1067_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_sd1034_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1045_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-atomic_eurec4a_2020-sd1061-20200117T000000-20200302T235959-1_minutes-v1.1589307121602_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-atomic_eurec4a_2020-sd1026-20200117T000000-20200302T235959-1_minutes-v1.1589306725934_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_4-shark-2018-sd1001-20180315T000000-20180529T235959-1_minutes-v1.1581626958976_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_2017_sd1002_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1005_2017_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1040_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-atomic_eurec4a_2020-sd1060-20200117T000000-20200302T235959-1_minutes-v1.1589306886594_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_2017_sd1003_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_4-shark-2018-sd1004-20180315T000000-20180617T235959-1_minutes-v1.1581627077777_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1006_2018_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-atlantic_to_med_2019_to_2020-sd1030-20191018T101200-20200717T134559-1_minutes-v1.1595626086288_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-atlantic_to_med_2019_to_2020-sd1053-20191018T110000-20200717T134559-1_minutes-v1.1595634214633_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2018_sd1027_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1044_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1039_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1069_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2018_sd1025_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_4-baja_2018-sd1002-20180411T180000-20180611T055959-1_minutes-v1_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2018_sd1028_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1068_2019_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1046_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone-gen_5-antarctica_circumnavigation_2019-sd1020-20190119T040000-20190803T043000-1_minutes-v1.1564884498845_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_arctic_2017_sd1001_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/PMEL_Arctic_2015_sd126-ALL-1_min-v1_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_tpos_sd1006_2017_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/PMEL_Arctic_2015_sd128-ALL-1_min-v1_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../saildrone_data/saildrone_west_coast_survey_2019_sd1043_JPLv5.0_8dy_20210613norep_20210613_20211116.nc']

# %%
#Taking parameters of longitudes and latitudes and returning saildrone files that contain data w/in parameters
def by_region ():
    
    #### PARAMETERS::: 
    # make sure lowerlat < upperlat since no test is done below to simplify the code
    lowerlat = int(input('Lower latitude value: '))
    upperlat = int(input('Upper latitude value: '))  
    # same caution as lat, long range (-180:180)
    lowerlong = int(input('Lower longitutde value: '))
    upperlong = int(input('Upper longitude value: '))
    
    
    
    ### Initializing name list and length of such as 0
    saildrone_name_list = []
    #nameList_len = len(saildrone_name_list)
    ltime, llat, llon, ltemp, lsal, = list(), list(), list(), list(), list()
    ### Filtering data: ds2 = lat, ds3 = lon
    for i in fns:
        ds = xr.open_dataset(i)
        ds2 = ds.where((ds.lat > lowerlat) & (ds.lat < upperlat), drop = True)
        ds3 = ds2.where((ds2.lon > lowerlong) & (ds2.lon < upperlong), drop = True)
        #print(len(ds.lon), len(ds3.lon))
        
        
        
    
        ds.close()
        if ((len(ds3.lon) > 0)): 
            saildrone_name_list.append(i)
            ltime.extend(ds3.time.data)
            llat.extend(ds3.lat.data)
            llon.extend(ds3.lon.data)
            ltemp.extend(ds3.TEMP_CTD_MEAN.data)
            lsal.extend(ds3.SAL_CTD_MEAN.data)

    ds_new = xr.Dataset(
        data_vars=dict(
            latitude=(['time'], llat),
            longitude=(['time'], llon),
            temperature = (['time'], ltemp),
            salinity = (['time'], lsal),
        coords=dict(time=ltime)))
            
    nameList_len = len(saildrone_name_list)
    print(nameList_len)
    return ds_new
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <module>
#      38         lsal.extend(ds3.SAL_CTD_MEAN.data)
#      39 type(ltime)
# ---> 40 ds_new = xr.Dataset(
#      41     data_vars=dict(
#      42         latitude=(['time'], llat),
#      43         longitude=(['time'], llon),
#      44         temperature = (['time'], ltemp),
#      45         salinity = (['time'], lsal),
#      46     coords=dict(time=ltime)))
#      48 nameList_len = len(saildrone_name_list)
#      49 print(nameList_len)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py:749, in Dataset.__init__(self, data_vars, coords, attrs)
#     746 if isinstance(coords, Dataset):
#     747     coords = coords.variables
# --> 749 variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#     750     data_vars, coords, compat="broadcast_equals"
#     751 )
#     753 self._attrs = dict(attrs) if attrs is not None else None
#     754 self._close = None
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/merge.py:483, in merge_data_and_coords(data, coords, compat, join)
#     481 explicit_coords = coords.keys()
#     482 indexes = dict(_extract_indexes_from_coords(coords))
# --> 483 return merge_core(
#     484     objects, compat, join, explicit_coords=explicit_coords, indexes=indexes
#     485 )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/merge.py:632, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     628 coerced = coerce_pandas_values(objects)
#     629 aligned = deep_align(
#     630     coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     631 )
# --> 632 collected = collect_variables_and_indexes(aligned)
#     634 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#     635 variables, out_indexes = merge_collected(
#     636     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     637 )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/merge.py:291, in collect_variables_and_indexes(list_of_mappings)
#     288     indexes.pop(name, None)
#     289     append_all(coords, indexes)
# --> 291 variable = as_variable(variable, name=name)
#     293 if variable.dims == (name,):
#     294     idx_variable = variable.to_index_variable()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/variable.py:128, in as_variable(obj, name)
#     126     obj = Variable(obj.name, obj)
#     127 elif isinstance(obj, (set, dict)):
# --> 128     raise TypeError(f"variable {name!r} has invalid type {type(obj)!r}")
#     129 elif name is not None:
#     130     data = as_compatible_data(obj)
#
# TypeError: variable 'coords' has invalid type <class 'dict'>

# %%
ltime
# Out:
# [numpy.datetime64('2018-07-17T18:35:00.000000000'),
#  numpy.datetime64('2018-07-17T19:22:00.000000000'),
#  numpy.datetime64('2018-07-18T00:00:30.000000000'),
#  numpy.datetime64('2018-07-18T05:12:30.000000000'),
#  numpy.datetime64('2018-07-18T07:58:30.000000000'),
#  numpy.datetime64('2018-07-18T10:33:50.890052356'),
#  numpy.datetime64('2018-07-18T15:16:00.000000000'),
#  numpy.datetime64('2018-07-18T18:13:00.000000000'),
#  numpy.datetime64('2018-07-18T21:12:30.000000000'),
#  numpy.datetime64('2018-07-19T01:04:00.000000000'),
#  numpy.datetime64('2018-07-19T02:01:32.307692307'),
#  numpy.datetime64('2018-07-19T03:46:00.000000000'),
#  numpy.datetime64('2018-07-19T06:25:30.000000000'),
#  numpy.datetime64('2018-07-19T09:26:00.000000000'),
#  numpy.datetime64('2018-07-19T12:58:30.000000000'),
#  numpy.datetime64('2018-07-19T13:05:54.102564102'),
#  numpy.datetime64('2018-07-19T16:47:00.000000000'),
#  numpy.datetime64('2018-07-19T18:14:30.000000000'),
#  numpy.datetime64('2018-07-20T07:13:00.000000000'),
#  numpy.datetime64('2018-07-20T10:43:16.406250000'),
#  numpy.datetime64('2018-07-22T03:28:21.978021978'),
#  numpy.datetime64('2018-07-22T14:23:00.000000000'),
#  numpy.datetime64('2018-07-23T05:44:52.679874869'),
#  numpy.datetime64('2018-07-24T18:27:00.000000000'),
#  numpy.datetime64('2018-07-25T03:06:51.884498480'),
#  numpy.datetime64('2018-07-25T22:04:00.152542372'),
#  numpy.datetime64('2018-07-26T23:00:00.000000000'),
#  numpy.datetime64('2018-07-27T07:14:30.000000000'),
#  numpy.datetime64('2018-07-28T02:17:21.198044009'),
#  numpy.datetime64('2018-07-28T07:03:17.142857142'),
#  numpy.datetime64('2018-07-28T10:59:51.344019728'),
#  numpy.datetime64('2018-07-29T04:48:29.820359281'),
#  numpy.datetime64('2018-07-29T09:08:30.000000000'),
#  numpy.datetime64('2018-07-29T11:52:22.775510204'),
#  numpy.datetime64('2018-07-29T20:58:01.372549019'),
#  numpy.datetime64('2018-07-30T00:34:00.000000000'),
#  numpy.datetime64('2018-07-30T08:31:21.167108753'),
#  numpy.datetime64('2018-07-30T13:09:34.817518248'),
#  numpy.datetime64('2018-07-30T20:04:57.062314540'),
#  numpy.datetime64('2018-07-30T23:21:08.431372549'),
#  numpy.datetime64('2018-07-31T10:00:19.253731343'),
#  numpy.datetime64('2018-07-31T20:23:00.000000000'),
#  numpy.datetime64('2018-07-31T22:30:00.000000000'),
#  numpy.datetime64('2018-08-01T00:26:30.000000000'),
#  numpy.datetime64('2018-08-01T06:22:47.444933920'),
#  numpy.datetime64('2018-08-01T19:54:45.869017632'),
#  numpy.datetime64('2018-08-02T08:09:26.850000000'),
#  numpy.datetime64('2018-08-02T16:00:00.000000000'),
#  numpy.datetime64('2018-08-02T17:47:30.000000000'),
#  numpy.datetime64('2018-08-02T19:29:00.000000000'),
#  numpy.datetime64('2018-08-02T20:17:10.537634408'),
#  numpy.datetime64('2018-08-02T22:43:30.069284064'),
#  numpy.datetime64('2018-08-03T12:42:30.000000000'),
#  numpy.datetime64('2018-08-18T02:43:00.000000000'),
#  numpy.datetime64('2018-08-19T02:48:00.000000000'),
#  numpy.datetime64('2018-08-20T02:21:20.495689655'),
#  numpy.datetime64('2018-08-22T19:20:19.196556671'),
#  numpy.datetime64('2018-08-29T10:18:30.000000000'),
#  numpy.datetime64('2018-09-06T08:58:37.017994858'),
#  numpy.datetime64('2018-09-06T21:20:28.598130841'),
#  numpy.datetime64('2018-09-07T07:24:41.772151898'),
#  numpy.datetime64('2018-09-07T21:22:00.000000000'),
#  numpy.datetime64('2018-09-09T10:47:25.917159763'),
#  numpy.datetime64('2018-09-10T00:03:00.000000000'),
#  numpy.datetime64('2018-09-10T17:35:50.405561993'),
#  numpy.datetime64('2018-09-12T11:34:06.842105263'),
#  numpy.datetime64('2018-09-21T21:06:31.520165460'),
#  numpy.datetime64('2018-09-22T04:01:25.526932084'),
#  numpy.datetime64('2018-09-23T02:23:00.000000000'),
#  numpy.datetime64('2018-09-23T06:23:30.000000000'),
#  numpy.datetime64('2018-09-23T10:29:30.000000000'),
#  numpy.datetime64('2018-09-23T14:15:00.000000000'),
#  numpy.datetime64('2018-09-23T16:26:00.000000000'),
#  numpy.datetime64('2018-09-23T18:48:30.000000000'),
#  numpy.datetime64('2018-09-23T22:20:00.000000000'),
#  numpy.datetime64('2018-09-24T00:08:30.000000000'),
#  numpy.datetime64('2018-09-24T01:51:00.000000000'),
#  numpy.datetime64('2018-09-24T04:56:30.000000000'),
#  numpy.datetime64('2018-09-24T08:13:30.000000000'),
#  numpy.datetime64('2018-09-25T02:21:40.631578947'),
#  numpy.datetime64('2018-09-25T04:29:27.171717171'),
#  numpy.datetime64('2018-09-25T06:33:04.594594594'),
#  numpy.datetime64('2018-09-25T20:58:45.454545454'),
#  numpy.datetime64('2018-09-26T01:04:30.000000000'),
#  numpy.datetime64('2018-09-26T04:45:30.000000000'),
#  numpy.datetime64('2018-09-26T12:09:30.000000000'),
#  numpy.datetime64('2018-09-26T20:44:00.000000000'),
#  numpy.datetime64('2018-09-27T03:19:00.000000000'),
#  numpy.datetime64('2018-09-27T08:47:00.000000000'),
#  numpy.datetime64('2018-09-27T12:13:00.000000000'),
#  numpy.datetime64('2018-09-27T14:54:30.000000000'),
#  numpy.datetime64('2018-09-27T19:05:00.000000000'),
#  numpy.datetime64('2018-09-27T22:40:00.000000000'),
#  numpy.datetime64('2018-09-28T10:40:53.362831858'),
#  numpy.datetime64('2018-09-28T12:19:48.709677419'),
#  numpy.datetime64('2018-09-28T15:05:08.823529411'),
#  numpy.datetime64('2018-09-29T02:29:30.000000000'),
#  numpy.datetime64('2018-09-29T12:29:00.000000000'),
#  numpy.datetime64('2018-09-30T03:31:37.290502793'),
#  numpy.datetime64('2018-09-30T11:39:27.339449541'),
#  numpy.datetime64('2018-09-30T21:25:00.000000000'),
#  numpy.datetime64('2018-10-01T06:10:30.000000000'),
#  numpy.datetime64('2018-10-01T18:10:30.000000000'),
#  numpy.datetime64('2018-10-02T06:24:00.000000000'),
#  numpy.datetime64('2018-10-02T16:42:00.000000000'),
#  numpy.datetime64('2018-10-02T23:07:30.000000000'),
#  numpy.datetime64('2018-10-03T04:17:30.000000000'),
#  numpy.datetime64('2018-10-03T11:00:30.000000000'),
#  numpy.datetime64('2018-10-03T19:32:30.000000000'),
#  numpy.datetime64('2018-10-04T15:50:33.279742765'),
#  numpy.datetime64('2018-10-05T10:32:43.948051948'),
#  numpy.datetime64('2018-10-05T17:24:49.811320754'),
#  numpy.datetime64('2018-10-06T00:55:30.000000000'),
#  numpy.datetime64('2018-10-06T03:23:00.000000000'),
#  numpy.datetime64('2018-10-06T04:58:00.000000000'),
#  numpy.datetime64('2018-10-06T06:36:00.000000000'),
#  numpy.datetime64('2018-10-06T09:49:30.000000000'),
#  numpy.datetime64('2018-10-06T13:04:00.000000000'),
#  numpy.datetime64('2018-10-06T16:15:30.000000000'),
#  numpy.datetime64('2018-10-06T19:27:00.000000000'),
#  numpy.datetime64('2018-10-06T21:25:00.000000000'),
#  numpy.datetime64('2018-10-06T22:44:00.000000000'),
#  numpy.datetime64('2018-10-06T23:51:00.000000000'),
#  numpy.datetime64('2018-10-07T10:17:52.352941176'),
#  numpy.datetime64('2018-10-07T13:56:12.406015037'),
#  numpy.datetime64('2018-10-07T16:16:53.125000000'),
#  numpy.datetime64('2018-10-08T02:59:00.000000000'),
#  numpy.datetime64('2018-10-08T04:50:30.000000000'),
#  numpy.datetime64('2018-10-08T07:39:30.000000000'),
#  numpy.datetime64('2018-10-08T11:44:30.000000000'),
#  numpy.datetime64('2018-10-08T16:11:00.000000000'),
#  numpy.datetime64('2018-10-08T20:36:00.000000000'),
#  numpy.datetime64('2018-10-08T23:20:00.000000000'),
#  numpy.datetime64('2018-10-09T01:05:30.000000000'),
#  numpy.datetime64('2018-10-09T02:30:30.000000000'),
#  numpy.datetime64('2018-10-09T04:47:00.000000000'),
#  numpy.datetime64('2018-10-09T08:34:30.000000000'),
#  numpy.datetime64('2018-10-09T11:16:30.000000000'),
#  numpy.datetime64('2018-10-10T00:36:00.000000000'),
#  numpy.datetime64('2018-10-10T04:04:30.000000000'),
#  numpy.datetime64('2018-10-10T10:04:00.000000000'),
#  numpy.datetime64('2018-10-10T13:34:00.000000000'),
#  numpy.datetime64('2018-10-10T17:18:30.000000000'),
#  numpy.datetime64('2018-10-10T23:11:30.000000000'),
#  numpy.datetime64('2018-10-11T06:52:30.000000000'),
#  numpy.datetime64('2018-10-11T16:36:00.000000000'),
#  numpy.datetime64('2018-10-11T23:36:30.000000000'),
#  numpy.datetime64('2018-10-12T06:31:00.000000000'),
#  numpy.datetime64('2018-10-12T15:27:30.000000000'),
#  numpy.datetime64('2018-10-12T19:58:30.000000000'),
#  numpy.datetime64('2018-10-13T01:13:00.000000000'),
#  numpy.datetime64('2018-10-13T10:36:47.234042553'),
#  numpy.datetime64('2018-10-13T21:04:00.000000000'),
#  numpy.datetime64('2018-10-14T02:34:00.000000000'),
#  numpy.datetime64('2018-10-14T14:28:24.674556213'),
#  numpy.datetime64('2018-10-15T05:20:00.000000000'),
#  numpy.datetime64('2018-10-15T11:14:30.000000000'),
#  numpy.datetime64('2018-10-15T18:39:30.000000000'),
#  numpy.datetime64('2018-10-15T21:43:05.853658536'),
#  numpy.datetime64('2018-10-16T01:32:13.076923076'),
#  numpy.datetime64('2018-10-16T04:15:30.000000000'),
#  numpy.datetime64('2018-10-16T08:48:30.000000000'),
#  numpy.datetime64('2018-10-16T14:06:30.000000000'),
#  numpy.datetime64('2018-10-16T19:26:00.000000000'),
#  numpy.datetime64('2018-10-16T22:59:00.000000000'),
#  numpy.datetime64('2018-10-17T01:20:30.000000000'),
#  numpy.datetime64('2018-10-17T03:03:30.000000000'),
#  numpy.datetime64('2018-10-17T07:11:00.000000000'),
#  numpy.datetime64('2018-10-17T14:39:00.000000000'),
#  numpy.datetime64('2018-10-17T19:31:30.000000000'),
#  numpy.datetime64('2018-10-18T11:47:00.000000000'),
#  numpy.datetime64('2018-10-18T14:37:30.000000000'),
#  numpy.datetime64('2018-10-18T19:10:30.000000000'),
#  numpy.datetime64('2018-10-18T22:22:00.000000000'),
#  numpy.datetime64('2018-10-19T00:33:30.000000000'),
#  numpy.datetime64('2018-10-19T03:54:00.000000000'),
#  numpy.datetime64('2018-10-19T08:07:30.000000000'),
#  numpy.datetime64('2018-10-19T12:20:30.000000000'),
#  numpy.datetime64('2018-10-19T16:07:30.000000000'),
#  numpy.datetime64('2018-10-19T19:18:30.000000000'),
#  numpy.datetime64('2018-10-19T21:17:30.000000000'),
#  numpy.datetime64('2018-10-19T22:58:30.000000000'),
#  numpy.datetime64('2018-10-20T17:00:33.333333333'),
#  numpy.datetime64('2018-10-20T17:29:37.514792899'),
#  numpy.datetime64('2018-10-20T20:05:36.705882352'),
#  numpy.datetime64('2018-10-21T13:49:30.000000000'),
#  numpy.datetime64('2018-10-21T15:36:00.000000000'),
#  numpy.datetime64('2018-10-21T18:13:30.000000000'),
#  numpy.datetime64('2018-10-21T21:50:30.000000000'),
#  numpy.datetime64('2018-10-21T23:46:30.000000000'),
#  numpy.datetime64('2018-10-22T01:40:00.000000000'),
#  numpy.datetime64('2018-10-22T05:36:00.000000000'),
#  numpy.datetime64('2018-10-22T09:13:17.454545454'),
#  numpy.datetime64('2018-10-22T10:14:00.000000000'),
#  numpy.datetime64('2018-10-22T12:55:30.000000000'),
#  numpy.datetime64('2018-10-22T16:09:30.000000000'),
#  numpy.datetime64('2018-10-22T21:32:00.000000000'),
#  numpy.datetime64('2018-10-23T13:17:31.863354037'),
#  numpy.datetime64('2018-10-23T19:14:50.994371482'),
#  numpy.datetime64('2018-10-24T13:34:00.000000000'),
#  numpy.datetime64('2018-10-24T16:01:00.000000000'),
#  numpy.datetime64('2018-10-24T18:07:30.000000000'),
#  numpy.datetime64('2018-10-24T22:00:00.000000000'),
#  numpy.datetime64('2018-10-25T00:08:30.000000000'),
#  numpy.datetime64('2018-10-25T02:16:00.000000000'),
#  numpy.datetime64('2018-10-25T06:07:00.000000000'),
#  numpy.datetime64('2018-10-25T09:35:30.000000000'),
#  numpy.datetime64('2018-10-25T11:49:30.000000000'),
#  numpy.datetime64('2018-10-25T13:28:30.000000000'),
#  numpy.datetime64('2018-10-25T16:20:30.000000000'),
#  numpy.datetime64('2018-10-25T20:22:30.000000000'),
#  numpy.datetime64('2018-10-25T23:17:30.000000000'),
#  numpy.datetime64('2018-10-26T06:47:56.232558139'),
#  numpy.datetime64('2018-10-26T15:47:30.000000000'),
#  numpy.datetime64('2018-10-26T21:41:30.000000000'),
#  numpy.datetime64('2018-10-27T00:47:30.000000000'),
#  numpy.datetime64('2018-10-27T02:53:30.000000000'),
#  numpy.datetime64('2018-10-27T05:25:00.000000000'),
#  numpy.datetime64('2018-10-27T08:23:00.000000000'),
#  numpy.datetime64('2018-10-27T11:57:30.000000000'),
#  numpy.datetime64('2018-10-27T15:40:30.000000000'),
#  numpy.datetime64('2018-10-27T19:35:30.000000000'),
#  numpy.datetime64('2018-10-27T22:48:30.000000000'),
#  numpy.datetime64('2018-10-28T18:35:02.022471910'),
#  numpy.datetime64('2018-10-28T19:04:17.647058823'),
#  numpy.datetime64('2018-10-28T21:32:02.315112540'),
#  numpy.datetime64('2018-10-28T22:07:25.000000000'),
#  numpy.datetime64('2018-10-29T01:12:00.000000000'),
#  numpy.datetime64('2018-10-29T22:38:00.000000000'),
#  numpy.datetime64('2018-10-30T00:07:30.000000000'),
#  numpy.datetime64('2018-10-30T01:38:00.000000000'),
#  numpy.datetime64('2018-10-30T04:19:00.000000000'),
#  numpy.datetime64('2018-10-30T07:07:00.000000000'),
#  numpy.datetime64('2018-10-30T09:46:30.000000000'),
#  numpy.datetime64('2018-10-30T11:19:30.000000000'),
#  numpy.datetime64('2018-10-30T13:17:30.000000000'),
#  numpy.datetime64('2018-10-30T16:16:00.000000000'),
#  numpy.datetime64('2018-10-30T19:25:30.000000000'),
#  numpy.datetime64('2018-10-31T05:50:30.000000000'),
#  numpy.datetime64('2018-10-31T10:12:00.000000000'),
#  numpy.datetime64('2018-10-31T15:46:30.000000000'),
#  numpy.datetime64('2018-10-31T21:13:30.000000000'),
#  numpy.datetime64('2018-10-31T23:48:00.000000000'),
#  numpy.datetime64('2018-11-01T02:18:30.000000000'),
#  numpy.datetime64('2018-11-01T06:14:00.000000000'),
#  numpy.datetime64('2018-11-01T10:38:00.000000000'),
#  numpy.datetime64('2018-11-01T15:45:00.000000000'),
#  numpy.datetime64('2018-11-01T20:31:30.000000000'),
#  numpy.datetime64('2018-11-01T22:56:00.000000000'),
#  numpy.datetime64('2018-11-01T23:40:00.000000000'),
#  numpy.datetime64('2018-11-02T04:59:30.000000000'),
#  numpy.datetime64('2018-11-02T12:07:30.000000000'),
#  numpy.datetime64('2018-11-02T15:13:00.000000000'),
#  numpy.datetime64('2018-11-03T02:00:06.315789473'),
#  numpy.datetime64('2018-11-03T04:02:00.000000000'),
#  numpy.datetime64('2018-11-03T07:38:00.000000000'),
#  numpy.datetime64('2018-11-03T10:20:30.000000000'),
#  numpy.datetime64('2018-11-03T12:06:00.000000000'),
#  numpy.datetime64('2018-11-03T15:09:00.000000000'),
#  numpy.datetime64('2018-11-03T19:38:00.000000000'),
#  numpy.datetime64('2018-11-04T00:21:30.000000000'),
#  numpy.datetime64('2018-11-04T04:24:00.000000000'),
#  numpy.datetime64('2018-11-04T09:20:30.000000000'),
#  numpy.datetime64('2018-11-04T11:03:00.000000000'),
#  numpy.datetime64('2018-11-04T13:24:00.000000000'),
#  numpy.datetime64('2018-11-04T18:05:30.000000000'),
#  numpy.datetime64('2018-11-04T22:24:00.000000000'),
#  numpy.datetime64('2018-11-05T01:08:30.000000000'),
#  numpy.datetime64('2018-11-05T03:13:26.603773584'),
#  numpy.datetime64('2018-11-05T07:32:00.000000000'),
#  numpy.datetime64('2018-11-05T11:49:30.000000000'),
#  numpy.datetime64('2018-11-05T14:59:30.000000000'),
#  numpy.datetime64('2018-11-05T16:40:30.000000000'),
#  numpy.datetime64('2018-11-05T18:46:00.000000000'),
#  numpy.datetime64('2018-11-05T22:14:00.000000000'),
#  numpy.datetime64('2018-11-06T01:46:30.000000000'),
#  numpy.datetime64('2018-11-06T05:09:30.000000000'),
#  numpy.datetime64('2018-11-06T08:33:30.000000000'),
#  numpy.datetime64('2018-11-06T10:24:00.000000000'),
#  numpy.datetime64('2018-11-06T12:21:30.000000000'),
#  numpy.datetime64('2018-11-06T16:24:00.000000000'),
#  numpy.datetime64('2018-11-06T19:48:00.000000000'),
#  numpy.datetime64('2018-11-07T09:44:30.000000000'),
#  numpy.datetime64('2018-11-07T12:19:00.000000000'),
#  numpy.datetime64('2018-11-07T17:16:30.000000000'),
#  numpy.datetime64('2018-11-07T21:39:00.000000000'),
#  numpy.datetime64('2018-11-07T23:41:30.000000000'),
#  numpy.datetime64('2018-11-08T00:29:00.000000000'),
#  numpy.datetime64('2018-11-08T03:15:00.000000000'),
#  numpy.datetime64('2018-11-08T07:46:30.000000000'),
#  numpy.datetime64('2018-11-08T12:14:00.000000000'),
#  numpy.datetime64('2018-11-08T18:14:00.000000000'),
#  numpy.datetime64('2018-11-09T02:51:00.000000000'),
#  numpy.datetime64('2018-11-09T11:06:00.000000000'),
#  numpy.datetime64('2018-11-09T19:15:30.000000000'),
#  numpy.datetime64('2018-11-10T07:27:30.000000000'),
#  numpy.datetime64('2018-11-10T19:27:30.000000000'),
#  numpy.datetime64('2018-11-11T00:38:30.000000000'),
#  numpy.datetime64('2018-11-11T05:57:00.000000000'),
#  numpy.datetime64('2018-11-11T22:53:00.000000000'),
#  numpy.datetime64('2018-11-12T12:00:30.000000000'),
#  numpy.datetime64('2018-11-13T23:05:30.000000000'),
#  numpy.datetime64('2018-11-15T18:46:30.000000000'),
#  numpy.datetime64('2018-11-16T19:54:30.000000000'),
#  numpy.datetime64('2018-11-17T19:54:30.000000000'),
#  numpy.datetime64('2018-11-18T15:04:30.000000000'),
#  numpy.datetime64('2018-11-19T07:39:30.000000000'),
#  numpy.datetime64('2018-11-19T19:32:00.000000000'),
#  numpy.datetime64('2018-11-20T06:40:30.000000000'),
#  numpy.datetime64('2018-11-20T15:44:00.000000000'),
#  numpy.datetime64('2018-11-21T02:33:30.000000000'),
#  numpy.datetime64('2018-11-21T10:22:30.000000000'),
#  numpy.datetime64('2018-11-21T15:59:30.000000000'),
#  numpy.datetime64('2018-11-21T19:53:00.000000000'),
#  numpy.datetime64('2018-11-22T01:53:30.000000000'),
#  numpy.datetime64('2018-11-22T07:19:00.000000000'),
#  numpy.datetime64('2018-11-22T13:22:00.000000000'),
#  numpy.datetime64('2018-11-23T04:00:00.000000000'),
#  numpy.datetime64('2018-11-23T14:15:00.000000000'),
#  numpy.datetime64('2018-11-24T09:17:30.000000000'),
#  numpy.datetime64('2018-11-25T04:54:13.487603305'),
#  numpy.datetime64('2019-07-22T11:34:00.000000000'),
#  numpy.datetime64('2019-07-23T01:53:58.823529411'),
#  numpy.datetime64('2019-07-23T11:41:30.000000000'),
#  numpy.datetime64('2019-07-23T18:13:30.000000000'),
#  numpy.datetime64('2019-07-23T22:35:30.000000000'),
#  numpy.datetime64('2019-07-24T07:20:00.000000000'),
#  numpy.datetime64('2019-07-24T15:53:30.000000000'),
#  numpy.datetime64('2019-07-24T17:48:00.000000000'),
#  numpy.datetime64('2019-07-24T20:30:30.000000000'),
#  numpy.datetime64('2019-07-24T23:16:30.000000000'),
#  numpy.datetime64('2019-07-25T00:37:30.000000000'),
#  numpy.datetime64('2019-07-25T04:01:32.400000000'),
#  numpy.datetime64('2019-07-25T04:10:30.000000000'),
#  numpy.datetime64('2019-07-25T07:28:30.000000000'),
#  numpy.datetime64('2019-07-25T10:25:00.000000000'),
#  numpy.datetime64('2019-07-25T13:25:00.000000000'),
#  numpy.datetime64('2019-07-25T17:57:20.672268907'),
#  numpy.datetime64('2019-07-25T18:16:02.425876010'),
#  numpy.datetime64('2019-07-26T01:06:35.887850467'),
#  numpy.datetime64('2019-07-26T02:38:00.000000000'),
#  numpy.datetime64('2019-07-26T06:57:30.000000000'),
#  numpy.datetime64('2019-07-26T07:54:47.412587412'),
#  numpy.datetime64('2019-07-26T14:29:30.000000000'),
#  numpy.datetime64('2019-07-26T18:47:15.341506129'),
#  numpy.datetime64('2019-07-27T00:57:30.000000000'),
#  numpy.datetime64('2019-07-27T02:11:00.000000000'),
#  numpy.datetime64('2019-07-27T08:08:30.000000000'),
#  numpy.datetime64('2019-08-27T01:57:30.000000000'),
#  numpy.datetime64('2019-08-27T05:53:30.000000000'),
#  numpy.datetime64('2019-08-27T10:27:30.000000000'),
#  numpy.datetime64('2019-08-27T15:40:00.000000000'),
#  numpy.datetime64('2019-08-27T21:10:30.000000000'),
#  numpy.datetime64('2019-08-28T00:19:30.000000000'),
#  numpy.datetime64('2019-08-28T06:09:00.000000000'),
#  numpy.datetime64('2019-08-28T15:25:00.000000000'),
#  numpy.datetime64('2019-08-28T21:35:30.000000000'),
#  numpy.datetime64('2019-08-29T03:28:00.000000000'),
#  numpy.datetime64('2019-08-29T11:04:30.000000000'),
#  numpy.datetime64('2019-08-29T20:51:30.000000000'),
#  numpy.datetime64('2019-08-30T06:14:00.000000000'),
#  numpy.datetime64('2019-08-30T16:59:30.000000000'),
#  numpy.datetime64('2019-08-31T04:25:30.000000000'),
#  numpy.datetime64('2019-08-31T11:09:00.000000000'),
#  numpy.datetime64('2019-08-31T14:53:30.000000000'),
#  numpy.datetime64('2019-08-31T21:59:00.000000000'),
#  numpy.datetime64('2019-09-01T13:32:03.068181818'),
#  numpy.datetime64('2019-09-01T15:40:30.000000000'),
#  numpy.datetime64('2019-09-02T03:49:30.000000000'),
#  numpy.datetime64('2019-09-02T11:25:00.000000000'),
#  numpy.datetime64('2019-09-02T16:35:00.000000000'),
#  numpy.datetime64('2019-09-02T18:45:00.000000000'),
#  numpy.datetime64('2019-09-02T21:46:00.000000000'),
#  numpy.datetime64('2019-09-03T02:01:00.000000000'),
#  numpy.datetime64('2019-09-03T09:03:39.810426540'),
#  numpy.datetime64('2019-09-03T10:40:30.000000000'),
#  numpy.datetime64('2019-09-03T19:39:45.298013245'),
#  numpy.datetime64('2019-09-03T22:33:00.000000000'),
#  numpy.datetime64('2019-09-04T04:13:00.000000000'),
#  numpy.datetime64('2019-09-04T08:25:30.000000000'),
#  numpy.datetime64('2019-09-04T11:09:30.000000000'),
#  numpy.datetime64('2019-09-04T14:40:00.000000000'),
#  numpy.datetime64('2019-09-04T17:53:00.000000000'),
#  numpy.datetime64('2019-09-04T20:31:00.000000000'),
#  numpy.datetime64('2019-09-04T23:06:00.000000000'),
#  numpy.datetime64('2019-09-05T01:27:30.000000000'),
#  numpy.datetime64('2019-09-05T03:20:00.000000000'),
#  numpy.datetime64('2019-09-05T05:38:30.000000000'),
#  numpy.datetime64('2019-09-05T09:09:30.000000000'),
#  numpy.datetime64('2019-09-05T11:59:30.000000000'),
#  numpy.datetime64('2019-09-05T17:16:30.000000000'),
#  numpy.datetime64('2019-09-05T22:41:30.000000000'),
#  numpy.datetime64('2019-09-06T02:53:30.000000000'),
#  numpy.datetime64('2019-09-06T08:21:30.000000000'),
#  numpy.datetime64('2019-09-06T11:49:30.000000000'),
#  numpy.datetime64('2019-09-06T13:52:00.000000000'),
#  numpy.datetime64('2019-09-08T07:10:23.538461538'),
#  numpy.datetime64('2019-07-23T07:12:55.890410958'),
#  numpy.datetime64('2019-07-26T10:31:30.000000000'),
#  numpy.datetime64('2019-07-27T14:33:13.531914893'),
#  numpy.datetime64('2019-07-28T21:15:30.000000000'),
#  numpy.datetime64('2019-07-29T01:32:30.000000000'),
#  numpy.datetime64('2019-07-29T16:57:00.000000000'),
#  numpy.datetime64('2019-07-29T22:28:04.748201438'),
#  numpy.datetime64('2019-07-30T00:36:30.000000000'),
#  numpy.datetime64('2019-08-03T05:47:28.369028006'),
#  numpy.datetime64('2019-08-03T19:08:10.105263157'),
#  numpy.datetime64('2019-08-04T22:02:23.793103448'),
#  numpy.datetime64('2019-08-07T07:16:30.000000000'),
#  numpy.datetime64('2019-08-07T15:59:00.000000000'),
#  numpy.datetime64('2019-08-07T22:03:29.469026548'),
#  numpy.datetime64('2019-08-09T14:04:45.066079295'),
#  numpy.datetime64('2019-08-10T13:42:05.538461538'),
#  numpy.datetime64('2019-08-11T19:56:30.000000000'),
#  numpy.datetime64('2019-08-13T09:34:00.839694656'),
#  numpy.datetime64('2019-08-13T19:10:29.466192170'),
#  numpy.datetime64('2019-08-14T08:53:30.000000000'),
#  numpy.datetime64('2019-08-15T09:59:03.789473684'),
#  numpy.datetime64('2019-08-15T14:05:30.000000000'),
#  numpy.datetime64('2019-08-16T11:57:22.420494699'),
#  numpy.datetime64('2019-08-17T09:05:00.000000000'),
#  numpy.datetime64('2019-08-18T14:07:50.834575260'),
#  numpy.datetime64('2019-08-20T06:41:58.770491803'),
#  numpy.datetime64('2019-08-21T07:52:54.763860369'),
#  numpy.datetime64('2019-08-21T21:28:56.976744186'),
#  numpy.datetime64('2019-08-22T11:58:30.000000000'),
#  numpy.datetime64('2019-08-25T10:04:00.000000000'),
#  numpy.datetime64('2019-08-25T15:16:30.000000000'),
#  numpy.datetime64('2019-08-25T20:56:30.000000000'),
#  numpy.datetime64('2019-08-26T01:45:30.000000000'),
#  numpy.datetime64('2019-08-26T07:31:26.511627906'),
#  numpy.datetime64('2019-08-26T17:56:32.864321608'),
#  numpy.datetime64('2019-08-27T05:23:30.000000000'),
#  numpy.datetime64('2019-08-27T16:07:30.000000000'),
#  numpy.datetime64('2019-08-28T00:37:30.000000000'),
#  numpy.datetime64('2019-08-28T03:47:00.000000000'),
#  numpy.datetime64('2019-08-28T18:37:30.000000000'),
#  numpy.datetime64('2019-08-29T11:36:46.764705882'),
#  numpy.datetime64('2019-08-29T18:48:28.524590163'),
#  numpy.datetime64('2019-08-30T01:46:00.000000000'),
#  numpy.datetime64('2019-08-30T08:53:00.000000000'),
#  numpy.datetime64('2019-08-30T15:23:00.000000000'),
#  numpy.datetime64('2019-08-30T20:16:00.000000000'),
#  numpy.datetime64('2019-08-31T00:14:30.000000000'),
#  numpy.datetime64('2019-08-31T03:28:00.000000000'),
#  numpy.datetime64('2019-08-31T10:02:00.000000000'),
#  numpy.datetime64('2019-08-31T18:12:30.000000000'),
#  numpy.datetime64('2019-09-01T03:53:30.000000000'),
#  numpy.datetime64('2019-09-01T14:05:00.000000000'),
#  numpy.datetime64('2018-07-08T00:00:00.000000000'),
#  numpy.datetime64('2018-07-08T01:15:00.000000000'),
#  numpy.datetime64('2018-07-08T04:04:00.000000000'),
#  numpy.datetime64('2018-07-08T07:14:00.000000000'),
#  numpy.datetime64('2018-07-08T11:09:45.000000000'),
#  numpy.datetime64('2018-07-08T12:11:00.000000000'),
#  numpy.datetime64('2018-07-08T14:07:00.000000000'),
#  numpy.datetime64('2018-07-08T17:27:30.000000000'),
#  numpy.datetime64('2018-07-08T21:37:00.000000000'),
#  numpy.datetime64('2018-07-09T00:32:00.000000000'),
#  numpy.datetime64('2018-07-09T05:43:51.542553191'),
#  numpy.datetime64('2018-07-09T09:51:42.950819672'),
#  numpy.datetime64('2018-07-09T14:38:30.000000000'),
#  numpy.datetime64('2018-07-09T18:49:00.000000000'),
#  numpy.datetime64('2018-07-10T01:35:30.000000000'),
#  numpy.datetime64('2018-07-10T08:48:00.000000000'),
#  numpy.datetime64('2018-07-10T13:35:09.536423841'),
#  numpy.datetime64('2018-07-10T14:51:00.000000000'),
#  numpy.datetime64('2018-07-10T19:54:00.000000000'),
#  numpy.datetime64('2018-07-10T23:14:30.000000000'),
#  numpy.datetime64('2018-07-11T02:24:30.000000000'),
#  numpy.datetime64('2018-07-11T07:31:15.167286245'),
#  numpy.datetime64('2018-07-11T10:36:52.300884955'),
#  numpy.datetime64('2018-07-11T14:28:40.733944954'),
#  numpy.datetime64('2018-07-14T23:10:30.000000000'),
#  numpy.datetime64('2018-07-17T08:43:30.000000000'),
#  numpy.datetime64('2018-07-17T15:14:20.198019801'),
#  numpy.datetime64('2018-07-17T19:41:08.700000000'),
#  numpy.datetime64('2018-07-17T23:46:59.423076923'),
#  numpy.datetime64('2018-07-18T09:04:00.000000000'),
#  numpy.datetime64('2018-07-19T07:29:00.642570281'),
#  numpy.datetime64('2018-07-19T23:05:00.000000000'),
#  numpy.datetime64('2018-07-20T02:25:00.000000000'),
#  numpy.datetime64('2018-07-20T04:10:50.335570469'),
#  numpy.datetime64('2018-07-20T10:25:00.000000000'),
#  numpy.datetime64('2018-07-20T18:04:43.200000000'),
#  numpy.datetime64('2018-07-20T19:43:00.000000000'),
#  numpy.datetime64('2018-07-21T05:48:30.000000000'),
#  numpy.datetime64('2018-07-21T17:48:30.000000000'),
#  numpy.datetime64('2018-07-22T12:55:48.793774319'),
#  numpy.datetime64('2018-07-23T08:56:00.000000000'),
#  numpy.datetime64('2018-07-24T07:21:00.000000000'),
#  numpy.datetime64('2018-07-24T18:07:17.985257985'),
#  numpy.datetime64('2018-07-25T08:49:36.909090909'),
#  numpy.datetime64('2018-07-25T20:03:00.000000000'),
#  numpy.datetime64('2018-07-26T03:02:30.000000000'),
#  numpy.datetime64('2018-08-01T20:03:00.000000000'),
#  numpy.datetime64('2018-08-02T00:37:30.000000000'),
#  numpy.datetime64('2018-08-02T07:08:30.000000000'),
#  numpy.datetime64('2018-08-02T13:54:53.207547169'),
#  numpy.datetime64('2018-08-02T20:08:19.559471365'),
#  numpy.datetime64('2018-08-03T03:32:30.000000000'),
#  numpy.datetime64('2018-08-03T12:07:00.000000000'),
#  numpy.datetime64('2018-08-08T14:48:30.000000000'),
#  numpy.datetime64('2018-08-09T01:10:00.000000000'),
#  numpy.datetime64('2018-08-09T02:31:30.000000000'),
#  numpy.datetime64('2018-08-09T09:42:00.000000000'),
#  numpy.datetime64('2018-08-09T18:59:30.000000000'),
#  numpy.datetime64('2018-08-09T22:30:30.000000000'),
#  numpy.datetime64('2018-08-10T08:40:00.000000000'),
#  numpy.datetime64('2018-08-10T20:09:00.000000000'),
#  numpy.datetime64('2018-08-10T22:45:30.000000000'),
#  numpy.datetime64('2018-08-11T09:36:10.054305663'),
#  numpy.datetime64('2018-08-12T02:38:00.000000000'),
#  numpy.datetime64('2018-08-12T21:39:30.000000000'),
#  numpy.datetime64('2018-08-13T06:40:30.000000000'),
#  numpy.datetime64('2018-08-13T18:53:00.000000000'),
#  numpy.datetime64('2018-08-13T23:37:00.000000000'),
#  numpy.datetime64('2018-08-14T01:29:30.000000000'),
#  numpy.datetime64('2018-08-14T09:13:29.150943396'),
#  numpy.datetime64('2018-08-14T17:34:41.730449251'),
#  numpy.datetime64('2018-08-16T06:18:11.612903225'),
#  numpy.datetime64('2018-08-17T08:17:00.000000000'),
#  numpy.datetime64('2018-08-17T17:00:30.000000000'),
#  numpy.datetime64('2018-08-17T22:57:00.000000000'),
#  numpy.datetime64('2018-08-18T14:02:47.327586206'),
#  numpy.datetime64('2018-08-18T14:20:30.000000000'),
#  numpy.datetime64('2018-08-19T01:25:30.000000000'),
#  numpy.datetime64('2018-08-19T10:28:00.000000000'),
#  numpy.datetime64('2018-08-19T21:49:33.488372093'),
#  numpy.datetime64('2018-08-21T00:43:30.000000000'),
#  numpy.datetime64('2018-08-21T12:48:00.000000000'),
#  numpy.datetime64('2018-08-22T00:52:00.000000000'),
#  numpy.datetime64('2018-08-22T05:44:30.000000000'),
#  numpy.datetime64('2018-08-22T16:53:00.000000000'),
#  numpy.datetime64('2018-08-23T03:00:00.000000000'),
#  numpy.datetime64('2018-08-23T11:06:37.058823529'),
#  numpy.datetime64('2018-08-23T13:56:18.571428571'),
#  numpy.datetime64('2018-08-23T17:52:00.000000000'),
#  numpy.datetime64('2018-08-23T22:39:00.000000000'),
#  numpy.datetime64('2018-08-24T18:45:30.000000000'),
#  numpy.datetime64('2018-08-24T21:49:30.000000000'),
#  numpy.datetime64('2018-08-25T00:05:00.000000000'),
#  numpy.datetime64('2018-08-25T07:11:24.480600750'),
#  numpy.datetime64('2018-08-25T12:49:14.415584415'),
#  numpy.datetime64('2018-08-25T19:31:30.000000000'),
#  numpy.datetime64('2018-08-26T06:43:30.000000000'),
#  numpy.datetime64('2018-08-26T17:48:30.000000000'),
#  numpy.datetime64('2018-08-26T22:24:00.000000000'),
#  numpy.datetime64('2018-08-26T23:49:00.000000000'),
#  numpy.datetime64('2018-08-27T01:27:00.000000000'),
#  numpy.datetime64('2018-08-27T13:27:00.000000000'),
#  numpy.datetime64('2018-08-28T00:19:00.000000000'),
#  numpy.datetime64('2018-08-28T20:35:57.578475336'),
#  numpy.datetime64('2018-08-29T08:43:00.000000000'),
#  numpy.datetime64('2018-08-29T15:56:00.000000000'),
#  numpy.datetime64('2018-08-29T20:09:30.000000000'),
#  numpy.datetime64('2018-08-29T23:24:00.000000000'),
#  numpy.datetime64('2018-08-30T00:08:30.000000000'),
#  numpy.datetime64('2018-08-30T00:19:00.000000000'),
#  numpy.datetime64('2018-08-30T06:27:53.583815028'),
#  numpy.datetime64('2018-08-30T14:55:40.883720930'),
#  numpy.datetime64('2018-08-30T20:21:00.000000000'),
#  numpy.datetime64('2018-08-30T22:35:00.000000000'),
#  numpy.datetime64('2018-08-31T11:57:49.586330935'),
#  numpy.datetime64('2018-08-31T21:22:30.000000000'),
#  numpy.datetime64('2018-09-08T00:52:00.000000000'),
#  numpy.datetime64('2018-09-08T05:27:00.000000000'),
#  numpy.datetime64('2018-09-08T13:58:30.000000000'),
#  numpy.datetime64('2018-09-09T08:26:00.000000000'),
#  numpy.datetime64('2018-09-14T19:44:30.000000000'),
#  numpy.datetime64('2018-09-17T02:46:00.000000000'),
#  numpy.datetime64('2018-09-17T05:39:59.100642398'),
#  numpy.datetime64('2018-09-17T05:44:30.000000000'),
#  numpy.datetime64('2018-09-17T10:44:31.652542372'),
#  numpy.datetime64('2018-09-17T20:22:00.000000000'),
#  numpy.datetime64('2018-09-19T12:23:00.000000000'),
#  numpy.datetime64('2018-09-19T21:36:44.516129032'),
#  numpy.datetime64('2018-09-20T01:12:00.000000000'),
#  numpy.datetime64('2018-09-20T12:27:50.344234079'),
#  numpy.datetime64('2018-09-20T23:46:00.000000000'),
#  numpy.datetime64('2018-09-20T23:53:30.000000000'),
#  numpy.datetime64('2018-09-21T13:43:38.616796047'),
#  numpy.datetime64('2018-09-22T13:29:00.000000000'),
#  numpy.datetime64('2018-09-22T19:36:30.000000000'),
#  numpy.datetime64('2018-09-22T23:41:30.000000000'),
#  numpy.datetime64('2018-09-23T08:23:00.000000000'),
#  numpy.datetime64('2018-09-23T10:26:36.622015142'),
#  numpy.datetime64('2018-09-23T19:43:30.000000000'),
#  numpy.datetime64('2018-09-26T15:41:30.000000000'),
#  numpy.datetime64('2018-09-27T02:48:30.000000000'),
#  numpy.datetime64('2018-09-27T13:55:00.000000000'),
#  numpy.datetime64('2018-09-28T05:36:00.000000000'),
#  numpy.datetime64('2018-09-28T17:36:00.000000000'),
#  numpy.datetime64('2018-09-29T08:25:24.664310954'),
#  numpy.datetime64('2018-09-29T09:25:48.097385031'),
#  numpy.datetime64('2018-10-01T21:03:11.321266968'),
#  numpy.datetime64('2018-10-02T10:21:06.978998384'),
#  numpy.datetime64('2018-10-03T01:41:57.081081081'),
#  numpy.datetime64('2018-10-03T06:33:00.000000000'),
#  numpy.datetime64('2018-10-03T16:54:10.181818181'),
#  numpy.datetime64('2018-10-10T16:50:27.662337662'),
#  numpy.datetime64('2018-10-11T12:00:30.000000000'),
#  numpy.datetime64('2018-10-12T03:11:00.000000000'),
#  numpy.datetime64('2018-10-12T09:19:30.000000000'),
#  numpy.datetime64('2018-10-12T15:14:30.000000000'),
#  numpy.datetime64('2018-10-13T13:49:00.000000000'),
#  numpy.datetime64('2018-10-13T20:37:30.000000000'),
#  numpy.datetime64('2018-10-14T06:01:00.000000000'),
#  numpy.datetime64('2018-10-14T16:58:20.911528150'),
#  numpy.datetime64('2018-10-14T17:27:03.260869565'),
#  numpy.datetime64('2018-10-15T01:47:30.000000000'),
#  numpy.datetime64('2018-10-15T04:29:00.000000000'),
#  numpy.datetime64('2018-10-15T09:48:30.000000000'),
#  numpy.datetime64('2018-10-15T18:24:23.076923076'),
#  numpy.datetime64('2018-10-16T05:03:34.601226993'),
#  numpy.datetime64('2018-10-16T10:29:30.000000000'),
#  numpy.datetime64('2018-10-16T14:23:00.000000000'),
#  numpy.datetime64('2018-10-16T19:19:30.000000000'),
#  numpy.datetime64('2018-10-16T22:49:30.000000000'),
#  numpy.datetime64('2018-10-17T01:29:00.000000000'),
#  numpy.datetime64('2018-10-17T04:28:30.000000000'),
#  numpy.datetime64('2018-10-17T09:55:30.000000000'),
#  numpy.datetime64('2018-10-17T15:13:30.000000000'),
#  numpy.datetime64('2018-10-17T20:18:00.000000000'),
#  numpy.datetime64('2018-10-18T00:54:00.000000000'),
#  numpy.datetime64('2018-10-18T03:14:30.000000000'),
#  numpy.datetime64('2018-10-18T08:30:00.000000000'),
#  numpy.datetime64('2018-10-18T12:56:30.000000000'),
#  numpy.datetime64('2018-10-18T18:20:30.000000000'),
#  numpy.datetime64('2018-10-18T23:33:30.000000000'),
#  numpy.datetime64('2018-10-19T00:34:00.000000000'),
#  numpy.datetime64('2018-10-19T04:42:00.000000000'),
#  numpy.datetime64('2018-10-19T08:20:30.000000000'),
#  numpy.datetime64('2018-10-19T12:35:00.000000000'),
#  numpy.datetime64('2018-10-19T17:24:30.000000000'),
#  numpy.datetime64('2018-10-19T20:03:00.000000000'),
#  numpy.datetime64('2018-10-19T23:01:30.000000000'),
#  numpy.datetime64('2018-10-20T00:45:30.000000000'),
#  numpy.datetime64('2018-10-20T03:34:00.000000000'),
#  numpy.datetime64('2018-10-20T08:14:30.000000000'),
#  numpy.datetime64('2018-10-20T12:38:00.000000000'),
#  numpy.datetime64('2018-10-20T16:10:30.000000000'),
#  numpy.datetime64('2018-10-20T21:44:01.818181818'),
#  numpy.datetime64('2018-10-21T00:31:00.000000000'),
#  numpy.datetime64('2018-10-21T04:52:00.000000000'),
#  numpy.datetime64('2018-10-21T08:26:00.000000000'),
#  numpy.datetime64('2018-10-21T12:41:30.000000000'),
#  numpy.datetime64('2018-10-21T15:47:00.000000000'),
#  numpy.datetime64('2018-10-21T18:42:30.000000000'),
#  numpy.datetime64('2018-10-21T22:15:00.000000000'),
#  numpy.datetime64('2018-10-22T01:31:30.000000000'),
#  numpy.datetime64('2018-10-22T04:42:00.000000000'),
#  numpy.datetime64('2018-10-22T11:01:00.000000000'),
#  numpy.datetime64('2018-10-22T19:50:30.000000000'),
#  numpy.datetime64('2018-10-23T06:27:30.000000000'),
#  numpy.datetime64('2018-10-23T18:32:00.000000000'),
#  numpy.datetime64('2018-10-23T19:20:11.967213114'),
#  numpy.datetime64('2018-10-24T12:07:00.000000000'),
#  numpy.datetime64('2018-10-24T22:43:00.000000000'),
#  numpy.datetime64('2018-10-24T23:27:00.000000000'),
#  numpy.datetime64('2018-10-25T08:21:00.000000000'),
#  numpy.datetime64('2018-10-25T21:14:18.314606741'),
#  numpy.datetime64('2019-07-20T01:01:30.000000000'),
#  numpy.datetime64('2019-07-20T02:48:48.169014084'),
#  numpy.datetime64('2019-07-20T05:31:58.938053097'),
#  numpy.datetime64('2019-07-20T07:19:00.000000000'),
#  numpy.datetime64('2019-07-20T09:14:00.000000000'),
#  numpy.datetime64('2019-07-20T11:53:30.000000000'),
#  numpy.datetime64('2019-07-20T13:33:00.000000000'),
#  numpy.datetime64('2019-07-20T16:15:00.000000000'),
#  numpy.datetime64('2019-07-20T20:34:30.000000000'),
#  numpy.datetime64('2019-07-20T23:14:00.000000000'),
#  numpy.datetime64('2019-07-21T02:22:00.000000000'),
#  numpy.datetime64('2019-07-21T05:25:30.000000000'),
#  numpy.datetime64('2019-07-21T08:27:00.000000000'),
#  numpy.datetime64('2019-07-21T15:01:06.206896551'),
#  numpy.datetime64('2019-07-21T16:10:00.000000000'),
#  numpy.datetime64('2019-07-21T19:16:30.000000000'),
#  numpy.datetime64('2019-07-21T21:42:00.000000000'),
#  numpy.datetime64('2019-07-22T01:11:00.000000000'),
#  numpy.datetime64('2019-07-22T02:47:30.000000000'),
#  numpy.datetime64('2019-07-22T07:17:00.000000000'),
#  numpy.datetime64('2019-07-22T11:46:00.000000000'),
#  numpy.datetime64('2019-07-22T16:15:00.000000000'),
#  numpy.datetime64('2019-07-22T21:20:30.000000000'),
#  numpy.datetime64('2019-07-23T01:25:00.000000000'),
#  numpy.datetime64('2019-07-23T07:43:30.000000000'),
#  numpy.datetime64('2019-07-23T13:29:00.000000000'),
#  numpy.datetime64('2019-07-23T18:18:00.000000000'),
#  numpy.datetime64('2019-07-23T20:47:30.000000000'),
#  numpy.datetime64('2019-07-23T22:29:00.000000000'),
#  numpy.datetime64('2019-07-24T00:19:00.000000000'),
#  numpy.datetime64('2019-07-24T07:27:38.841698841'),
#  numpy.datetime64('2019-07-24T13:14:24.424778761'),
#  numpy.datetime64('2019-07-24T15:54:00.000000000'),
#  numpy.datetime64('2019-07-24T20:03:07.912087912'),
#  numpy.datetime64('2019-07-24T22:37:07.605633802'),
#  numpy.datetime64('2019-07-25T01:36:00.000000000'),
#  numpy.datetime64('2019-07-25T05:06:00.000000000'),
#  numpy.datetime64('2019-07-25T08:53:30.000000000'),
#  numpy.datetime64('2019-07-25T13:08:00.000000000'),
#  numpy.datetime64('2019-07-25T17:53:00.000000000'),
#  numpy.datetime64('2019-07-25T21:46:00.000000000'),
#  numpy.datetime64('2019-07-26T06:08:51.176470588'),
#  numpy.datetime64('2019-07-26T06:36:34.255319148'),
#  numpy.datetime64('2019-07-26T16:27:00.000000000'),
#  numpy.datetime64('2019-07-26T21:29:30.000000000'),
#  numpy.datetime64('2019-07-27T04:52:38.373382624'),
#  numpy.datetime64('2019-07-27T13:15:00.000000000'),
#  numpy.datetime64('2019-07-27T16:35:30.000000000'),
#  numpy.datetime64('2019-07-27T20:15:48.561151079'),
#  numpy.datetime64('2019-07-27T22:53:30.000000000'),
#  numpy.datetime64('2019-07-27T23:27:30.000000000'),
#  numpy.datetime64('2019-07-28T02:27:43.471698113'),
#  numpy.datetime64('2019-07-28T07:09:02.358078602'),
#  numpy.datetime64('2019-07-28T09:31:12.000000000'),
#  numpy.datetime64('2019-07-28T12:17:31.643835616'),
#  numpy.datetime64('2019-07-28T13:23:28.073394495'),
#  numpy.datetime64('2019-07-28T21:27:00.000000000'),
#  numpy.datetime64('2019-07-28T23:10:48.000000000'),
#  numpy.datetime64('2019-07-29T02:08:00.000000000'),
#  numpy.datetime64('2019-07-29T08:56:30.131578947'),
#  numpy.datetime64('2019-07-29T11:05:46.090909090'),
#  numpy.datetime64('2019-07-29T14:28:30.000000000'),
#  numpy.datetime64('2019-07-29T18:32:52.380952380'),
#  numpy.datetime64('2019-07-29T20:30:00.000000000'),
#  numpy.datetime64('2019-07-29T22:29:02.857142857'),
#  numpy.datetime64('2019-07-30T00:00:00.000000000'),
#  numpy.datetime64('2019-07-30T21:26:54.638783269'),
#  numpy.datetime64('2019-07-31T00:37:32.707182320'),
#  numpy.datetime64('2019-07-31T00:43:14.714828897'),
#  numpy.datetime64('2019-07-31T01:55:42.400000000'),
#  numpy.datetime64('2019-07-31T05:55:57.264957264'),
#  numpy.datetime64('2019-07-31T08:57:00.000000000'),
#  numpy.datetime64('2019-07-31T23:52:00.000000000'),
#  numpy.datetime64('2019-08-01T02:24:56.061776061'),
#  numpy.datetime64('2019-08-01T07:07:00.000000000'),
#  numpy.datetime64('2019-08-01T09:57:30.000000000'),
#  numpy.datetime64('2019-08-01T14:39:08.153310104'),
#  numpy.datetime64('2019-08-01T17:38:00.000000000'),
#  numpy.datetime64('2019-08-01T18:39:00.000000000'),
#  numpy.datetime64('2019-08-01T21:04:44.011461318'),
#  numpy.datetime64('2019-08-02T00:07:00.000000000'),
#  numpy.datetime64('2019-08-02T06:43:02.544861337'),
#  numpy.datetime64('2019-08-02T16:01:30.000000000'),
#  numpy.datetime64('2019-08-02T17:56:00.000000000'),
#  numpy.datetime64('2019-08-02T20:23:00.000000000'),
#  numpy.datetime64('2019-08-02T23:39:30.731707317'),
#  numpy.datetime64('2019-08-03T02:05:30.000000000'),
#  numpy.datetime64('2019-08-03T09:11:41.268292682'),
#  numpy.datetime64('2019-08-03T16:43:00.000000000'),
#  numpy.datetime64('2019-08-03T19:33:00.000000000'),
#  numpy.datetime64('2019-08-03T22:42:00.000000000'),
#  numpy.datetime64('2019-08-03T23:41:30.000000000'),
#  numpy.datetime64('2019-08-04T05:22:40.598802395'),
#  numpy.datetime64('2019-08-04T09:56:47.852760736'),
#  numpy.datetime64('2019-08-04T17:43:30.000000000'),
#  numpy.datetime64('2019-08-04T21:17:00.000000000'),
#  numpy.datetime64('2019-08-04T23:52:00.000000000'),
#  numpy.datetime64('2019-08-05T02:38:30.000000000'),
#  numpy.datetime64('2019-08-05T21:58:00.000000000'),
#  numpy.datetime64('2019-08-05T23:30:00.000000000'),
#  numpy.datetime64('2019-08-06T01:07:30.000000000'),
#  numpy.datetime64('2019-08-06T02:55:30.000000000'),
#  numpy.datetime64('2019-08-06T06:52:16.879795396'),
#  numpy.datetime64('2019-08-07T21:03:30.000000000'),
#  numpy.datetime64('2019-08-07T23:19:00.000000000'),
#  numpy.datetime64('2019-08-08T04:58:30.000000000'),
#  numpy.datetime64('2019-08-08T11:11:00.000000000'),
#  numpy.datetime64('2019-08-08T16:04:35.079365079'),
#  numpy.datetime64('2019-08-08T19:47:30.000000000'),
#  numpy.datetime64('2019-08-08T22:07:00.000000000'),
#  numpy.datetime64('2019-08-09T01:24:30.000000000'),
#  numpy.datetime64('2019-08-09T03:31:00.000000000'),
#  numpy.datetime64('2019-08-09T06:28:00.000000000'),
#  numpy.datetime64('2019-08-09T11:39:30.000000000'),
#  numpy.datetime64('2019-08-09T16:05:30.000000000'),
#  numpy.datetime64('2019-08-09T20:47:30.000000000'),
#  numpy.datetime64('2019-08-10T00:15:00.000000000'),
#  numpy.datetime64('2019-08-10T04:32:00.000000000'),
#  numpy.datetime64('2019-08-10T06:37:47.792207792'),
#  numpy.datetime64('2019-08-10T17:32:37.557251908'),
#  numpy.datetime64('2019-08-11T09:02:00.000000000'),
#  numpy.datetime64('2019-08-11T12:37:00.000000000'),
#  numpy.datetime64('2019-08-11T18:40:00.000000000'),
#  numpy.datetime64('2019-08-11T23:27:30.000000000'),
#  numpy.datetime64('2019-08-12T01:17:30.000000000'),
#  numpy.datetime64('2019-08-12T04:17:30.000000000'),
#  numpy.datetime64('2019-08-12T09:48:30.000000000'),
#  numpy.datetime64('2019-08-12T18:01:55.204678362'),
#  numpy.datetime64('2019-08-13T00:47:39.533527696'),
#  numpy.datetime64('2019-08-13T10:04:00.000000000'),
#  numpy.datetime64('2019-08-13T19:21:30.000000000'),
#  numpy.datetime64('2019-08-13T23:14:00.000000000'),
#  numpy.datetime64('2019-08-14T00:33:27.187500000'),
#  numpy.datetime64('2019-08-14T05:39:21.466666666'),
#  numpy.datetime64('2019-08-14T13:18:30.000000000'),
#  numpy.datetime64('2019-08-14T17:29:00.000000000'),
#  numpy.datetime64('2019-08-14T20:11:30.000000000'),
#  numpy.datetime64('2019-08-14T22:57:00.000000000'),
#  numpy.datetime64('2019-08-14T23:38:30.000000000'),
#  numpy.datetime64('2019-08-15T07:14:28.553054662'),
#  numpy.datetime64('2019-08-15T10:49:24.508009153'),
#  numpy.datetime64('2019-08-16T03:51:00.000000000'),
#  numpy.datetime64('2019-08-16T13:10:00.000000000'),
#  numpy.datetime64('2018-03-15T04:50:30.000000000'),
#  numpy.datetime64('2018-03-15T08:16:30.000000000'),
#  numpy.datetime64('2018-03-15T12:24:30.000000000'),
#  numpy.datetime64('2018-03-15T17:20:00.000000000'),
#  numpy.datetime64('2018-03-15T22:18:30.000000000'),
#  numpy.datetime64('2018-03-16T02:09:30.000000000'),
#  numpy.datetime64('2018-03-16T07:31:30.000000000'),
#  numpy.datetime64('2018-03-16T14:16:30.000000000'),
#  numpy.datetime64('2018-03-16T18:21:00.000000000'),
#  numpy.datetime64('2018-03-16T21:43:00.000000000'),
#  numpy.datetime64('2018-03-17T02:19:00.000000000'),
#  numpy.datetime64('2018-03-17T05:06:00.000000000'),
#  numpy.datetime64('2018-03-17T08:27:30.000000000'),
#  numpy.datetime64('2018-03-17T12:04:30.000000000'),
#  numpy.datetime64('2018-03-17T15:58:00.000000000'),
#  numpy.datetime64('2018-03-17T19:52:30.000000000'),
#  numpy.datetime64('2018-03-17T22:35:00.000000000'),
#  numpy.datetime64('2018-03-18T01:19:00.000000000'),
#  numpy.datetime64('2018-03-18T04:33:30.000000000'),
#  numpy.datetime64('2018-03-18T15:15:00.000000000'),
#  numpy.datetime64('2018-03-19T00:22:30.000000000'),
#  numpy.datetime64('2018-03-19T00:49:00.000000000'),
#  numpy.datetime64('2018-03-19T06:40:00.000000000'),
#  numpy.datetime64('2018-03-19T12:48:00.000000000'),
#  numpy.datetime64('2018-03-19T15:54:00.000000000'),
#  numpy.datetime64('2018-03-19T18:56:00.000000000'),
#  numpy.datetime64('2018-03-19T21:52:00.000000000'),
#  numpy.datetime64('2018-03-20T00:33:00.000000000'),
#  numpy.datetime64('2018-03-20T03:12:00.000000000'),
#  numpy.datetime64('2018-03-20T06:16:30.000000000'),
#  numpy.datetime64('2018-03-20T08:51:00.000000000'),
#  numpy.datetime64('2018-03-20T12:17:00.000000000'),
#  numpy.datetime64('2018-03-20T18:48:30.000000000'),
#  numpy.datetime64('2018-03-21T05:57:00.000000000'),
#  numpy.datetime64('2018-03-21T12:33:00.000000000'),
#  numpy.datetime64('2018-03-21T19:53:30.000000000'),
#  numpy.datetime64('2018-03-22T04:35:30.000000000'),
#  numpy.datetime64('2018-03-22T10:12:30.000000000'),
#  numpy.datetime64('2018-03-22T15:00:30.000000000'),
#  numpy.datetime64('2018-03-22T18:16:30.000000000'),
#  numpy.datetime64('2018-03-22T20:31:00.000000000'),
#  numpy.datetime64('2018-03-22T22:21:00.000000000'),
#  numpy.datetime64('2018-03-23T01:52:00.000000000'),
#  numpy.datetime64('2018-03-23T03:59:30.000000000'),
#  numpy.datetime64('2018-03-23T09:23:30.000000000'),
#  numpy.datetime64('2018-03-23T15:37:30.000000000'),
#  numpy.datetime64('2018-03-23T20:22:00.000000000'),
#  numpy.datetime64('2018-03-24T01:18:00.000000000'),
#  numpy.datetime64('2018-03-24T03:33:30.000000000'),
#  numpy.datetime64('2018-03-24T09:28:00.000000000'),
#  numpy.datetime64('2018-03-24T15:09:00.000000000'),
#  numpy.datetime64('2018-03-24T19:33:30.000000000'),
#  numpy.datetime64('2018-03-25T02:17:30.000000000'),
#  numpy.datetime64('2018-03-25T11:55:30.000000000'),
#  numpy.datetime64('2018-03-25T20:12:04.873096446'),
#  numpy.datetime64('2018-03-25T22:47:30.000000000'),
#  numpy.datetime64('2018-03-26T01:16:30.000000000'),
#  numpy.datetime64('2018-03-26T06:17:00.000000000'),
#  numpy.datetime64('2018-03-26T11:14:30.000000000'),
#  numpy.datetime64('2018-03-26T15:29:00.000000000'),
#  numpy.datetime64('2018-03-26T21:10:30.000000000'),
#  numpy.datetime64('2018-03-26T23:55:30.000000000'),
#  numpy.datetime64('2018-03-27T02:11:30.000000000'),
#  numpy.datetime64('2018-03-27T05:30:30.000000000'),
#  numpy.datetime64('2018-05-22T12:33:30.000000000'),
#  numpy.datetime64('2018-05-22T16:48:00.000000000'),
#  numpy.datetime64('2018-05-23T03:20:00.000000000'),
#  numpy.datetime64('2018-05-23T18:15:00.000000000'),
#  numpy.datetime64('2018-05-24T08:30:30.000000000'),
#  numpy.datetime64('2018-05-24T20:30:30.000000000'),
#  numpy.datetime64('2018-05-25T00:22:00.000000000'),
#  numpy.datetime64('2018-05-25T07:56:30.000000000'),
#  numpy.datetime64('2018-05-25T16:44:00.000000000'),
#  numpy.datetime64('2018-05-25T20:05:30.000000000'),
#  numpy.datetime64('2018-05-26T04:36:00.000000000'),
#  numpy.datetime64('2018-05-26T11:37:30.000000000'),
#  numpy.datetime64('2018-05-26T14:32:00.000000000'),
#  numpy.datetime64('2018-05-26T19:12:00.000000000'),
#  numpy.datetime64('2018-05-26T22:38:00.000000000'),
#  numpy.datetime64('2018-05-27T00:03:00.000000000'),
#  numpy.datetime64('2018-05-27T02:32:30.000000000'),
#  numpy.datetime64('2018-05-27T05:27:30.000000000'),
#  numpy.datetime64('2018-05-27T08:22:30.000000000'),
#  numpy.datetime64('2018-05-27T13:03:00.000000000'),
#  numpy.datetime64('2018-05-27T15:45:30.000000000'),
#  numpy.datetime64('2018-05-27T18:49:30.000000000'),
#  numpy.datetime64('2018-05-27T22:15:00.000000000'),
#  numpy.datetime64('2018-05-28T00:23:30.000000000'),
#  numpy.datetime64('2018-05-28T03:57:30.000000000'),
#  numpy.datetime64('2018-05-28T07:08:30.000000000'),
#  numpy.datetime64('2018-05-28T09:04:00.000000000'),
#  numpy.datetime64('2018-05-28T12:08:00.000000000'),
#  numpy.datetime64('2018-05-28T15:52:30.000000000'),
#  numpy.datetime64('2018-05-28T18:00:30.000000000'),
#  numpy.datetime64('2018-05-28T20:19:00.000000000'),
#  numpy.datetime64('2018-05-28T23:05:30.000000000'),
#  numpy.datetime64('2018-05-29T00:59:00.000000000'),
#  numpy.datetime64('2018-05-29T02:27:30.000000000'),
#  numpy.datetime64('2018-05-29T04:17:30.000000000'),
#  numpy.datetime64('2018-05-29T07:22:30.000000000'),
#  numpy.datetime64('2018-05-29T11:13:30.000000000'),
#  numpy.datetime64('2018-05-29T13:20:30.000000000'),
#  numpy.datetime64('2018-05-29T14:57:00.000000000'),
#  numpy.datetime64('2018-05-29T18:34:00.000000000'),
#  numpy.datetime64('2018-05-29T22:17:30.000000000'),
#  numpy.datetime64('2017-09-02T10:00:30.000000000'),
#  numpy.datetime64('2017-09-02T23:50:00.000000000'),
#  numpy.datetime64('2017-09-03T15:27:30.000000000'),
#  numpy.datetime64('2017-09-03T22:28:30.000000000'),
#  numpy.datetime64('2017-09-04T02:11:00.000000000'),
#  numpy.datetime64('2017-09-04T10:42:30.000000000'),
#  numpy.datetime64('2017-09-04T19:31:29.163346613'),
#  numpy.datetime64('2017-09-04T22:03:30.000000000'),
#  numpy.datetime64('2017-09-05T01:19:00.000000000'),
#  numpy.datetime64('2017-09-05T04:53:30.000000000'),
#  numpy.datetime64('2017-09-05T08:52:30.000000000'),
#  numpy.datetime64('2017-09-05T20:21:00.000000000'),
#  numpy.datetime64('2017-09-06T12:43:17.882736156'),
#  numpy.datetime64('2017-09-06T18:10:38.347826086'),
#  numpy.datetime64('2017-09-07T01:32:00.000000000'),
#  numpy.datetime64('2017-09-07T05:38:30.000000000'),
#  numpy.datetime64('2017-09-07T16:39:30.000000000'),
#  numpy.datetime64('2017-09-08T04:26:30.000000000'),
#  numpy.datetime64('2017-09-08T11:46:00.000000000'),
#  numpy.datetime64('2017-09-08T19:52:30.000000000'),
#  numpy.datetime64('2017-09-09T00:42:30.000000000'),
#  numpy.datetime64('2017-09-09T05:19:00.000000000'),
#  numpy.datetime64('2017-09-09T14:18:34.558303886'),
#  numpy.datetime64('2017-09-09T19:51:00.000000000'),
#  numpy.datetime64('2017-09-09T23:22:30.000000000'),
#  numpy.datetime64('2017-09-10T02:27:30.000000000'),
#  numpy.datetime64('2017-09-10T05:51:30.000000000'),
#  numpy.datetime64('2017-09-10T12:06:30.000000000'),
#  numpy.datetime64('2017-09-11T08:42:30.000000000'),
#  numpy.datetime64('2017-09-12T03:11:00.000000000'),
#  numpy.datetime64('2017-09-12T10:09:00.000000000'),
#  numpy.datetime64('2017-09-12T18:57:00.000000000'),
#  numpy.datetime64('2017-09-12T23:59:00.000000000'),
#  numpy.datetime64('2017-09-13T03:53:00.000000000'),
#  numpy.datetime64('2017-09-13T09:04:00.000000000'),
#  numpy.datetime64('2017-09-13T13:24:30.000000000'),
#  numpy.datetime64('2017-09-13T20:07:00.000000000'),
#  numpy.datetime64('2017-09-14T03:27:30.000000000'),
#  numpy.datetime64('2017-09-14T10:36:00.000000000'),
#  numpy.datetime64('2017-09-14T17:51:30.000000000'),
#  numpy.datetime64('2017-09-14T22:37:30.000000000'),
#  numpy.datetime64('2017-09-14T23:48:30.000000000'),
#  numpy.datetime64('2017-09-15T01:34:30.000000000'),
#  numpy.datetime64('2017-09-15T07:12:30.000000000'),
#  numpy.datetime64('2017-09-15T13:53:30.000000000'),
#  numpy.datetime64('2017-09-15T15:09:46.814814814'),
#  numpy.datetime64('2017-09-15T22:01:00.000000000'),
#  numpy.datetime64('2017-09-16T05:48:30.000000000'),
#  numpy.datetime64('2018-03-19T17:03:43.026315789'),
#  numpy.datetime64('2018-03-20T10:54:08.363171355'),
#  numpy.datetime64('2018-03-21T09:22:00.000000000'),
#  numpy.datetime64('2018-03-21T21:22:00.000000000'),
#  numpy.datetime64('2018-03-22T08:34:30.000000000'),
#  numpy.datetime64('2018-03-23T01:32:00.000000000'),
#  numpy.datetime64('2018-03-23T16:58:00.000000000'),
#  numpy.datetime64('2018-03-24T06:11:00.000000000'),
#  numpy.datetime64('2018-03-24T13:57:30.000000000'),
#  numpy.datetime64('2018-03-24T22:15:30.000000000'),
#  numpy.datetime64('2018-03-25T11:09:30.000000000'),
#  numpy.datetime64('2018-03-25T20:41:00.000000000'),
#  numpy.datetime64('2018-03-26T05:30:00.000000000'),
#  numpy.datetime64('2018-03-26T17:30:00.000000000'),
#  numpy.datetime64('2018-03-27T01:05:00.000000000'),
#  numpy.datetime64('2018-03-27T08:57:30.000000000'),
#  numpy.datetime64('2018-03-27T21:54:30.000000000'),
#  numpy.datetime64('2018-03-28T10:57:30.000000000'),
#  numpy.datetime64('2018-03-28T20:56:00.000000000'),
#  numpy.datetime64('2018-03-29T04:37:30.000000000'),
#  numpy.datetime64('2018-03-29T11:34:30.000000000'),
#  numpy.datetime64('2018-03-29T18:57:30.000000000'),
#  numpy.datetime64('2018-03-30T04:53:30.000000000'),
#  numpy.datetime64('2018-03-30T16:53:30.000000000'),
#  numpy.datetime64('2018-03-31T11:20:00.000000000'),
#  numpy.datetime64('2018-03-31T23:20:00.000000000'),
#  numpy.datetime64('2018-04-01T07:46:00.000000000'),
#  numpy.datetime64('2018-04-02T00:49:00.000000000'),
#  numpy.datetime64('2018-04-02T17:03:30.000000000'),
#  numpy.datetime64('2018-04-03T09:37:30.000000000'),
#  numpy.datetime64('2018-04-03T21:37:30.000000000'),
#  numpy.datetime64('2018-04-04T00:16:30.000000000'),
#  numpy.datetime64('2018-04-04T21:49:00.000000000'),
#  numpy.datetime64('2018-04-05T21:33:00.000000000'),
#  numpy.datetime64('2018-04-06T09:44:30.000000000'),
#  numpy.datetime64('2018-04-07T04:50:00.000000000'),
#  numpy.datetime64('2018-04-07T15:15:30.000000000'),
#  numpy.datetime64('2018-04-07T20:10:00.000000000'),
#  numpy.datetime64('2018-04-08T08:06:00.000000000'),
#  numpy.datetime64('2018-04-08T20:06:00.000000000'),
#  numpy.datetime64('2018-04-09T20:40:52.490857375'),
#  numpy.datetime64('2018-04-10T19:33:00.000000000'),
#  ...]

# %%
by_region()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <module>
# ----> 1 by_region()
#
# Input In [19], in by_region()
#      38         lsal.extend(ds3.SAL_CTD_MEAN.data)
#      39 type(ltime)
# ---> 40 ds_new = xr.Dataset(
#      41     data_vars=dict(
#      42         latitude=(['time'], llat),
#      43         longitude=(['time'], llon),
#      44         temperature = (['time'], ltemp),
#      45         salinity = (['time'], lsal),
#      46     coords=dict(time=ltime)))
#      48 nameList_len = len(saildrone_name_list)
#      49 print(nameList_len)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py:749, in Dataset.__init__(self, data_vars, coords, attrs)
#     746 if isinstance(coords, Dataset):
#     747     coords = coords.variables
# --> 749 variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#     750     data_vars, coords, compat="broadcast_equals"
#     751 )
#     753 self._attrs = dict(attrs) if attrs is not None else None
#     754 self._close = None
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/merge.py:483, in merge_data_and_coords(data, coords, compat, join)
#     481 explicit_coords = coords.keys()
#     482 indexes = dict(_extract_indexes_from_coords(coords))
# --> 483 return merge_core(
#     484     objects, compat, join, explicit_coords=explicit_coords, indexes=indexes
#     485 )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/merge.py:632, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     628 coerced = coerce_pandas_values(objects)
#     629 aligned = deep_align(
#     630     coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     631 )
# --> 632 collected = collect_variables_and_indexes(aligned)
#     634 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#     635 variables, out_indexes = merge_collected(
#     636     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     637 )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/merge.py:291, in collect_variables_and_indexes(list_of_mappings)
#     288     indexes.pop(name, None)
#     289     append_all(coords, indexes)
# --> 291 variable = as_variable(variable, name=name)
#     293 if variable.dims == (name,):
#     294     idx_variable = variable.to_index_variable()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/xarray/core/variable.py:128, in as_variable(obj, name)
#     126     obj = Variable(obj.name, obj)
#     127 elif isinstance(obj, (set, dict)):
# --> 128     raise TypeError(f"variable {name!r} has invalid type {type(obj)!r}")
#     129 elif name is not None:
#     130     data = as_compatible_data(obj)
#
# TypeError: variable 'coords' has invalid type <class 'dict'>
