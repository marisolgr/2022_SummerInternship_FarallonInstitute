# %% [markdown]
# ## Q1: salinity validation data in time

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import math
import glob
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import warnings
warnings.simplefilter('ignore') # filter some warning messages

# %%
ddir = '../saildrone data/'
fns = glob.glob(ddir+'*.nc')
#fns

# %%
plt.figure(figsize=(12,6))

d = 0
for i in fns:
    ds = xr.open_dataset(i)
    ds.close()  
    
    # 
    tmp = ds['SAL_CTD_MEAN'].where(ds['SAL_CTD_MEAN']<=50)
    # map
    plt.scatter(ds.time.dt.dayofyear,tmp-ds['smap_SSS'],5,ds['SAL_CTD_MEAN'],'o', cmap='jet')
    
plt.grid(zorder=0, alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12,6))

d = 0
for i in fns:
    ds = xr.open_dataset(i)
    ds.close()  
    
    # 
    tmp = ds['SAL_CTD_MEAN'].where(ds['SAL_CTD_MEAN']<=50)
    # map
    plt.scatter(ds.time.dt.dayofyear,tmp-ds['smap_SSS'],5,ds['TEMP_CTD_MEAN'],'o', cmap='jet')
    
plt.grid(zorder=0, alpha=0.5)
plt.show()
