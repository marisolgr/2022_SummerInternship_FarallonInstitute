# %% [markdown]
# ## Q1: salinity validation data in time

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import math
import glob
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import warnings
warnings.simplefilter('ignore') # filter some warning messages

# %%
ddir = '../data/'
fns = glob.glob(ddir+'*.nc')
fns
# Out:
# ['../data/saildrone-gen_5-arctic_misst_2019-sd1037-20190514T230000-20191011T183000-1_minutes-v1.1575487464625_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/saildrone_tpos_sd1029_2018_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/saildrone-gen_5-arctic_misst_2019-sd1036-20190514T230000-20191011T183000-1_minutes-v1.1575336154680_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/saildrone_tpos_sd1005_2018_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/saildrone_west_coast_survey_2018_sd1024_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/saildrone-gen_5-1021_atlantic-sd1021-20190525T000000-20191021T235959-1_minutes-v1.1571806429446_(1)_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/PMEL_Arctic_2016_sd126-ALL-1_min-v1_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
#  '../data/saildrone_west_coast_survey_2019_sd1038_JPLv5.0_8dy_20210613norep_20210613_20211116.nc',
# ...

# %%
plt.figure(figsize=(12,6))

d = 0
for i in fns:
    ds = xr.open_dataset(i)
    ds.close()  
    
    # 
    tmp = ds['SAL_CTD_MEAN'].where(ds['SAL_CTD_MEAN']<=50)
    # map
    plt.scatter(ds.time.dt.dayofyear,tmp-ds['sat_smap_sss'],5,ds['SAL_CTD_MEAN'],'o', cmap='jet')
    
plt.grid(zorder=0, alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12,6))

d = 0
for i in fns:
    ds = xr.open_dataset(i)
    ds.close()  
    
    # 
    tmp = ds['TEMP_CTD_MEAN'].where(ds['TEMP_CTD_MEAN']<=50)
    # map
    plt.scatter(ds.time.dt.dayofyear,tmp-ds['analysed_sst']+273.15,5,ds['TEMP_CTD_MEAN'],'o', cmap='jet')
    
plt.grid(zorder=0, alpha=0.5)
plt.show()
