# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import math
import glob
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import warnings
warnings.simplefilter('ignore') # filter some warning messages

# %%
ddir = '../saildrone data/'
fns = glob.glob(ddir+'*.nc')
#fns
# Out:
# ['../saildrone data/saildrone_tpos_sd1029_2018jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1039jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-atlantic_to_med_2019_to_2020-sd1053-20191018T110000-20200717T134559-1_minutes-v1.1595634214633jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2018_sd1026jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1044jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1005_2017jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1006_2017jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-arctic_misst_2019-sd1036-20190514T230000-20191011T183000-1_minutes-v1.1575336154680jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/PMEL_Arctic_2015_sd128-ALL-1_min-v1jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_2017_sd1001jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1040jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1047jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_sd1041_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_2017_sd1002jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-antarctica_circumnavigation_2019-sd1020-20190119T040000-20190803T043000-1_minutes-v1.1564884498845jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1043jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_4-shark-2018-sd1004-20180315T000000-20180617T235959-1_minutes-v1.1581627077777jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-atomic_eurec4a_2020-sd1061-20200117T000000-20200302T235959-1_minutes-v1.1589307121602jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1005_2018jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1069_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1006_2018jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1030_2018jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1068_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/PMEL_Arctic_2015_sd126-ALL-1_min-v1jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2018_sd1025jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_4-baja_2018-sd1002-20180411T180000-20180611T055959-1_minutes-v1jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_sd1033_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-atomic_eurec4a_2020-sd1060-20200117T000000-20200302T235959-1_minutes-v1.1589306886594jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1045jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-1021_atlantic-sd1021-20190525T000000-20191021T235959-1_minutes-v1.1571806429446_(1)jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_sd1035_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_sd1034_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-atlantic_to_med_2019_to_2020-sd1030-20191018T101200-20200717T134559-1_minutes-v1.1595626086288jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2018_sd1027jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/PMEL_Arctic_2016_sd128-ALL-1_min-v1jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1038jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-atomic_eurec4a_2020-sd1026-20200117T000000-20200302T235959-1_minutes-v1.1589306725934jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2018_sd1024jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_5-arctic_misst_2019-sd1037-20190514T230000-20191011T183000-1_minutes-v1.1575487464625jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_arctic_2017_sd1003jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone-gen_4-shark-2018-sd1001-20180315T000000-20180529T235959-1_minutes-v1.1581626958976jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1067_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_tpos_sd1066_2019jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2018_sd1028jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/saildrone_west_coast_survey_2019_sd1046jplv05.0_orbitalnorep_20211116.nc',
#  '../saildrone data/PMEL_Arctic_2016_sd126-ALL-1_min-v1jplv05.0_orbitalnorep_20211116.nc']

# %%
fig=plt.figure(figsize=(12,5),dpi=150)
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()
ax.add_feature(cfeature.LAND, color='lightgrey')
    
for i in fns:
    ds = xr.open_dataset(i)
    ds.close()  
    # map
    cb = ax.scatter(ds['lon'],ds['lat'], 5,ds['TEMP_CTD_MEAN'],'o', transform=ccrs.PlateCarree(), cmap='jet', vmin=0, vmax=30)

fig.colorbar(cb)
plt.show()

# %%
fig=plt.figure(figsize=(12,4),dpi=150)
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()
ax.add_feature(cfeature.LAND, color='lightgrey')
d=0   
for i in fns:
    ds = xr.open_dataset(i)
    ds.close()  
    # map
    cb = ax.scatter(ds['lon'],ds['lat'], 5,np.full(len(ds.lon),d),'.', transform=ccrs.PlateCarree(), cmap='jet', vmin=0, vmax=45)
    d += 1
fig.colorbar(cb)
plt.show()

# %%
len(fns)
# Out:
# 46
